# %%
# Change directory to VSCode workspace root so that relative path loads work correctly. Turn this addition off with the DataScience.changeDirOnImportExport setting
# ms-python.python added
import os
try:
	os.chdir(os.path.join(os.getcwd(), '..'))
	print(os.getcwd())
except:
	pass

# %%
import os
import pandas as pd
import numpy as np
import re
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
data_path = 'files/read_in.pkl'
reviews = pd.read_pickle(data_path)
review = reviews.copy()

# %%
data_path = 'files/review_final.pkl'
reviews = pd.read_pickle(data_path)

# %%
reviews.head()
# Out:
#                                               review  \
# 0  I had a enjoyable time during my stay there on...
# 1  My husband came to ATL on a business trip. We ...
# 2  This hotel is convenient for park and fly to A...
# 3  I had the pleasure of being served by Andrene ...
# 4  The room we were in was not sooooo great stain...
#
#                                      hotel_name           travel_type  \
# 0  Holiday Inn & Suites Atlanta Airport - North  Traveled on business
# 1  Holiday Inn & Suites Atlanta Airport - North  Traveled on business
# 2  Holiday Inn & Suites Atlanta Airport - North         Traveled solo
# 3  Holiday Inn & Suites Atlanta Airport - North  Traveled with family
# 4  Holiday Inn & Suites Atlanta Airport - North  Traveled with family
#
#                                                url_x  hotel_rating_review  \
# 0  https://www.tripadvisor.com/ShowUserReviews-g6...                    4
# ...

# %%
reviews.url_x.values[0]
# Out:
# 'https://www.tripadvisor.com/ShowUserReviews-g60898-d86197-r624899856-Holiday_Inn_Suites_Atlanta_Airport_North-Atlanta_Georgia.html'

# %%
reviews.columns
# Out:
# Index(['review', 'hotel_name', 'travel_type', 'url_x', 'hotel_rating_review',
#        'url_y', 'num_amenities', 'num_rooms', 'hotel_rating_hotel',
#        'low_price', 'high_price', 'Accessible rooms', 'Air conditioning',
#        'Airport transportation', 'Babysitting', 'Banquet Room', 'Bar/Lounge',
#        'Breakfast Available', 'Breakfast included',
#        'Business Center with Internet Access',
#        'Children Activities (Kid / Family Friendly)', 'Concierge',
#        'Conference Facilities', 'Dry Cleaning',
#        'Electric vehicle charging station', 'Family Rooms',
#        'Fitness Center with Gym / Workout Room',
#        'Free High Speed Internet (WiFi)', 'Free Internet', 'Free parking',
#        'Golf course', 'Heated pool', 'Hot Tub', 'Indoor pool', 'Kitchenette',
#        'Laundry Service', 'Meeting rooms', 'Microwave', 'Minibar',
#        'Multilingual Staff', 'Non-smoking hotel', 'Non-smoking rooms',
#        'Outdoor pool', 'Paid Internet', 'Paid Wifi',
# ...

# %%
cols = ['review','review_preds','hotel_name']
reviews[cols].head()
# Out:
#                                               review review_preds  \
# 0  I had a enjoyable time during my stay there on...          [6]
# 1  My husband came to ATL on a business trip. We ...        [196]
# 2  This hotel is convenient for park and fly to A...         [85]
# 3  I had the pleasure of being served by Andrene ...        [144]
# 4  The room we were in was not sooooo great stain...         [31]
#
#                                      hotel_name
# 0  Holiday Inn & Suites Atlanta Airport - North
# 1  Holiday Inn & Suites Atlanta Airport - North
# 2  Holiday Inn & Suites Atlanta Airport - North
# 3  Holiday Inn & Suites Atlanta Airport - North
# 4  Holiday Inn & Suites Atlanta Airport - North

# %%
cols = ['review','review_preds','hotel_name']
review_table = reviews[cols]

# %%
review_table['review_preds'] = review_table['review_preds'].apply(lambda x: x[0])
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
review_table['review_preds'].distinct
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-385fb13ce2d5> in <module>
# ----> 1 review_table['review_preds'].distinct
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'distinct'

# %%
review_table['review_preds'].distinct()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-aca698d56e49> in <module>
# ----> 1 review_table['review_preds'].distinct()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'distinct'

# %%
review_table['review_preds'].unique_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-b974bfb2dc74> in <module>
# ----> 1 review_table['review_preds'].unique_values()
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'unique_values'

# %%
review_table['review_preds'].unique()
# Out:
# array([  6, 196,  85, 144,  31, 121,   0,   8,  33,  37, 133, 197,  63,
#         35, 115,  91, 163, 117, 118, 188,  90,  46, 149,  20,  58, 145,
#        195,  49,  28, 190, 150,  97, 136, 159,  54,  50, 130,  70,  86,
#        126, 178,  65, 161,  94,  62,   9, 135, 167, 162,  40, 169,  21,
#         32, 158, 109, 102, 184,  26,   5,  67, 141,  51,  88,  16,  95,
#        140,  53, 198,  60, 134, 179,  83, 185,  30,  44, 192, 193,  99,
#         12,  48, 181,  19, 146, 191, 114, 164,  80, 131,  59,  77,  98,
#          4,  84,   7, 147, 152,  89,  41,  56,  39, 125, 183, 153,  76,
#         68, 108, 103, 139, 160, 168,  57, 171,   3,  38, 100, 157, 116,
#         36, 180,  29, 182, 143,  78,  79,  13, 110, 111, 177, 189, 166,
#         93, 175, 107, 176, 174, 101,  17,  52,  72,  82, 132, 138, 186,
#         23, 187, 105, 106,  27,  18, 129,  43,  34, 155,  74, 154,  10,
#         87, 112, 194,  25,  75,   1, 142, 127,  61, 124, 156, 199, 104,
# ...

# %%
review_table.describe()
# Out:
#         review_preds
# count  113624.000000
# mean      100.963300
# std        57.685213
# min         0.000000
# 25%        50.000000
# 50%       102.000000
# 75%       151.000000
# max       199.000000

# %%
review_table.to_csv('files/review_table.csv'.index=False)
# Out:
#   File "<ipython-input-15-df165185c8ac>", line 1
#     review_table.to_csv('files/review_table.csv'.index=False)
#                        ^
# SyntaxError: keyword can't be an expression

# %%
review_table.to_csv('files/review_table.csv',index=False)

# %%
reviews[['hotel_name','hotel_pred']]
# Out:
#                                                hotel_name  hotel_pred
# 0            Holiday Inn & Suites Atlanta Airport - North        21.0
# 1            Holiday Inn & Suites Atlanta Airport - North        21.0
# 2            Holiday Inn & Suites Atlanta Airport - North        21.0
# 3            Holiday Inn & Suites Atlanta Airport - North        21.0
# 4            Holiday Inn & Suites Atlanta Airport - North        21.0
# 5            Holiday Inn & Suites Atlanta Airport - North        21.0
# 6            Holiday Inn & Suites Atlanta Airport - North        21.0
# 7            Holiday Inn & Suites Atlanta Airport - North        21.0
# 8            Holiday Inn & Suites Atlanta Airport - North        21.0
# 9            Holiday Inn & Suites Atlanta Airport - North        21.0
# 10           Holiday Inn & Suites Atlanta Airport - North        21.0
# 11           Holiday Inn & Suites Atlanta Airport - North        21.0
# ...

# %%
hotel_table = reviews[['hotel_name','hotel_pred']]

# %%
hotel_table.drop_duplicates()
# Out:
#                                                hotel_name  hotel_pred
# 0            Holiday Inn & Suites Atlanta Airport - North        21.0
# 845                    SpringHill Suites Atlanta Downtown         4.0
# 964                    Drury Inn & Suites Atlanta Airport         7.0
# 1614            Renaissance Atlanta Airport Gateway Hotel        29.0
# 1873    Embassy Suites by Hilton Atlanta - at Centenni...        18.0
# 2689                    Omni Hotel at the Battery Atlanta        29.0
# 2996      Hampton Inn & Suites Atlanta Perimeter Dunwoody         7.0
# 3465              Hampton Inn & Suites Atlanta - Galleria         7.0
# 4112                   Hilton Garden Inn Atlanta Downtown         1.0
# 5973                          The Westin Buckhead Atlanta        14.0
# 6741             Georgia Tech Hotel and Conference Center         1.0
# 7846                         Hyatt Place Atlanta/Downtown         5.0
# ...

# %%
hotel_table = hotel_table.drop_duplicates()

# %%
hotel_table.to_csv('files/hotel_table.csv',index=False)
